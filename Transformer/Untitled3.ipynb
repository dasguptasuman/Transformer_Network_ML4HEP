# %%
import numpy as np


def readucr(filename):
    data = np.loadtxt(filename, delimiter="\t")
    y = data[:, 0]
    x = data[:, 1:]
    return x, y.astype(int)


root_url = "https://raw.githubusercontent.com/hfawaz/cd-diagram/master/FordA/"

x_train, y_train = readucr(root_url + "FordA_TRAIN.tsv")
x_test, y_test = readucr(root_url + "FordA_TEST.tsv")

x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))

n_classes = len(np.unique(y_train))

idx = np.random.permutation(len(x_train))
x_train = x_train[idx]
y_train = y_train[idx]

y_train[y_train == -1] = 0
y_test[y_test == -1] = 0

# %%
from tensorflow import keras
from tensorflow.keras import layers

# %%
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Attention and Normalization
    x = layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout
    )(inputs, inputs)
    x = layers.Dropout(dropout)(x)
    x = layers.LayerNormalization(epsilon=1e-6)(x)
    res = x + inputs

    # Feed Forward Part
    x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(res)
    x = layers.Dropout(dropout)(x)
    x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
    x = layers.LayerNormalization(epsilon=1e-6)(x)
    return x + res

# %%
def build_model(
    input_shape,
    head_size,
    num_heads,
    ff_dim,
    num_transformer_blocks,
    mlp_units,
    dropout=0,
    mlp_dropout=0,
):
    inputs = keras.Input(shape=input_shape)
    x = inputs
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    x = layers.GlobalAveragePooling1D(data_format="channels_first")(x)
    for dim in mlp_units:
        x = layers.Dense(dim, activation="relu")(x)
        x = layers.Dropout(mlp_dropout)(x)
    outputs = layers.Dense(n_classes, activation="softmax")(x)
    return keras.Model(inputs, outputs)

# %%
input_shape = x_train.shape[1:]

model = build_model(
    input_shape,
    head_size=256,
    num_heads=4,
    ff_dim=4,
    num_transformer_blocks=4,
    mlp_units=[128],
    mlp_dropout=0.4,
    dropout=0.25,
)

model.compile(
    loss="sparse_categorical_crossentropy",
    optimizer=keras.optimizers.Adam(learning_rate=1e-4),
    metrics=["sparse_categorical_accuracy"],
)
model.summary()

callbacks = [keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)]

model.fit(
    x_train,
    y_train,
    validation_split=0.2,
    epochs=200,
    batch_size=64,
    callbacks=callbacks,
)

model.evaluate(x_test, y_test, verbose=1)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 500, 1)]     0           []
#
#  multi_head_attention (MultiHea  (None, 500, 1)      7169        ['input_1[0][0]',
#  dAttention)                                                      'input_1[0][0]']
#
#  dropout (Dropout)              (None, 500, 1)       0           ['multi_head_attention[0][0]']
#
#  layer_normalization (LayerNorm  (None, 500, 1)      2           ['dropout[0][0]']
#  alization)
#
#  tf.__operators__.add (TFOpLamb  (None, 500, 1)      0           ['layer_normalization[0][0]',
#  da)                                                              'input_1[0][0]']
#
#  conv1d (Conv1D)                (None, 500, 4)       8           ['tf.__operators__.add[0][0]']
#
#  dropout_1 (Dropout)            (None, 500, 4)       0           ['conv1d[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 500, 1)       5           ['dropout_1[0][0]']
#
#  layer_normalization_1 (LayerNo  (None, 500, 1)      2           ['conv1d_1[0][0]']
#  rmalization)
#
#  tf.__operators__.add_1 (TFOpLa  (None, 500, 1)      0           ['layer_normalization_1[0][0]',
#  mbda)                                                            'tf.__operators__.add[0][0]']
#
#  multi_head_attention_1 (MultiH  (None, 500, 1)      7169        ['tf.__operators__.add_1[0][0]',
#  eadAttention)                                                    'tf.__operators__.add_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 500, 1)       0           ['multi_head_attention_1[0][0]']
#
#  layer_normalization_2 (LayerNo  (None, 500, 1)      2           ['dropout_2[0][0]']
#  rmalization)
#
#  tf.__operators__.add_2 (TFOpLa  (None, 500, 1)      0           ['layer_normalization_2[0][0]',
#  mbda)                                                            'tf.__operators__.add_1[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 500, 4)       8           ['tf.__operators__.add_2[0][0]']
#
#  dropout_3 (Dropout)            (None, 500, 4)       0           ['conv1d_2[0][0]']
#
#  conv1d_3 (Conv1D)              (None, 500, 1)       5           ['dropout_3[0][0]']
#
#  layer_normalization_3 (LayerNo  (None, 500, 1)      2           ['conv1d_3[0][0]']
#  rmalization)
#
#  tf.__operators__.add_3 (TFOpLa  (None, 500, 1)      0           ['layer_normalization_3[0][0]',
#  mbda)                                                            'tf.__operators__.add_2[0][0]']
#
#  multi_head_attention_2 (MultiH  (None, 500, 1)      7169        ['tf.__operators__.add_3[0][0]',
#  eadAttention)                                                    'tf.__operators__.add_3[0][0]']
#
#  dropout_4 (Dropout)            (None, 500, 1)       0           ['multi_head_attention_2[0][0]']
#
#  layer_normalization_4 (LayerNo  (None, 500, 1)      2           ['dropout_4[0][0]']
#  rmalization)
#
#  tf.__operators__.add_4 (TFOpLa  (None, 500, 1)      0           ['layer_normalization_4[0][0]',
#  mbda)                                                            'tf.__operators__.add_3[0][0]']
#
#  conv1d_4 (Conv1D)              (None, 500, 4)       8           ['tf.__operators__.add_4[0][0]']
#
#  dropout_5 (Dropout)            (None, 500, 4)       0           ['conv1d_4[0][0]']
#
#  conv1d_5 (Conv1D)              (None, 500, 1)       5           ['dropout_5[0][0]']
#
#  layer_normalization_5 (LayerNo  (None, 500, 1)      2           ['conv1d_5[0][0]']
#  rmalization)
#
#  tf.__operators__.add_5 (TFOpLa  (None, 500, 1)      0           ['layer_normalization_5[0][0]',
#  mbda)                                                            'tf.__operators__.add_4[0][0]']
#
#  multi_head_attention_3 (MultiH  (None, 500, 1)      7169        ['tf.__operators__.add_5[0][0]',
#  eadAttention)                                                    'tf.__operators__.add_5[0][0]']
#
#  dropout_6 (Dropout)            (None, 500, 1)       0           ['multi_head_attention_3[0][0]']
#
#  layer_normalization_6 (LayerNo  (None, 500, 1)      2           ['dropout_6[0][0]']
#  rmalization)
#
#  tf.__operators__.add_6 (TFOpLa  (None, 500, 1)      0           ['layer_normalization_6[0][0]',
#  mbda)                                                            'tf.__operators__.add_5[0][0]']
#
#  conv1d_6 (Conv1D)              (None, 500, 4)       8           ['tf.__operators__.add_6[0][0]']
#
#  dropout_7 (Dropout)            (None, 500, 4)       0           ['conv1d_6[0][0]']
#
#  conv1d_7 (Conv1D)              (None, 500, 1)       5           ['dropout_7[0][0]']
#
#  layer_normalization_7 (LayerNo  (None, 500, 1)      2           ['conv1d_7[0][0]']
#  rmalization)
#
#  tf.__operators__.add_7 (TFOpLa  (None, 500, 1)      0           ['layer_normalization_7[0][0]',
#  mbda)                                                            'tf.__operators__.add_6[0][0]']
#
#  global_average_pooling1d (Glob  (None, 500)         0           ['tf.__operators__.add_7[0][0]']
#  alAveragePooling1D)
#
#  dense (Dense)                  (None, 128)          64128       ['global_average_pooling1d[0][0]'
#                                                                  ]
#
#  dropout_8 (Dropout)            (None, 128)          0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 2)            258         ['dropout_8[0][0]']
#
# ==================================================================================================
# Total params: 93,130
# Trainable params: 93,130
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1
200
# 45/45 [==============================] - 22s 482ms/step - loss: 0.3716 - sparse_categorical_accuracy: 0.8389 - val_loss: 0.4585 - val_sparse_categorical_accuracy: 0.7864
# Epoch 35/200
# 45/45 [==============================] - 22s 482ms/step - loss: 0.3650 - sparse_categorical_accuracy: 0.8444 - val_loss: 0.4553 - val_sparse_categorical_accuracy: 0.7767
# Epoch 36/200
# 45/45 [==============================] - 22s 481ms/step - loss: 0.3462 - sparse_categorical_accuracy: 0.8597 - val_loss: 0.4516 - val_sparse_categorical_accuracy: 0.7836
# Epoch 37/200
# 45/45 [==============================] - 22s 483ms/step - loss: 0.3599 - sparse_categorical_accuracy: 0.8448 - val_loss: 0.4459 - val_sparse_categorical_accuracy: 0.7933
# Epoch 38/200
# 45/45 [==============================] - 22s 482ms/step - loss: 0.3411 - sparse_categorical_accuracy: 0.8615 - val_loss: 0.4438 - val_sparse_categorical_accuracy: 0.7975
# Epoch 39/200
# 45/45 [==============================] - 22s 482ms/step - loss: 0.3346 - sparse_categorical_accuracy: 0.8552 - val_loss: 0.4462 - val_sparse_categorical_accuracy: 0.7892
# Epoch 40/200
# 45/45 [==============================] - 22s 482ms/step - loss: 0.3347 - sparse_categorical_accuracy: 0.8660 - val_loss: 0.4400 - val_sparse_categorical_accuracy: 0.7933
# Epoch 41/200
# 45/45 [==============================] - 22s 482ms/step - loss: 0.3431 - sparse_categorical_accuracy: 0.8597 - val_loss: 0.4377 - val_sparse_categorical_accuracy: 0.7975
# Epoch 42/200
# 45/45 [==============================] - 22s 482ms/step - loss: 0.3274 - sparse_categorical_accuracy: 0.8726 - val_loss: 0.4366 - val_sparse_categorical_accuracy: 0.7961
# Epoch 43/200
# 45/45 [==============================] - 22s 481ms/step - loss: 0.3238 - sparse_categorical_accuracy: 0.8698 - val_loss: 0.4357 - val_sparse_categorical_accuracy: 0.7933
# Epoch 44/200
# 45/45 [==============================] - 22s 481ms/step - loss: 0.3281 - sparse_categorical_accuracy: 0.8653 - val_loss: 0.4329 - val_sparse_categorical_accuracy: 0.7989
# Epoch 45/200
# 45/45 [==============================] - 22s 482ms/step - loss: 0.3151 - sparse_categorical_accuracy: 0.8774 - val_loss: 0.4322 - val_sparse_categorical_accuracy: 0.7989
# Epoch 46/200
# 45/45 [==============================] - 22s 482ms/step - loss: 0.3140 - sparse_categorical_accuracy: 0.8701 - val_loss: 0.4339 - val_sparse_categorical_accuracy: 0.7961
# Epoch 47/200
# 45/45 [==============================] - 22s 482ms/step - loss: 0.3110 - sparse_categorical_accuracy: 0.8708 - val_loss: 0.4254 - val_sparse_categorical_accuracy: 0.8031
# Epoch 48/200
# 45/45 [==============================] - 22s 482ms/step - loss: 0.3089 - sparse_categorical_accuracy: 0.8809 - val_loss: 0.4238 - val_sparse_categorical_accuracy: 0.8058
# Epoch 49/200
# 45/45 [==============================] - 22s 481ms/step - loss: 0.3071 - sparse_categorical_accuracy: 0.8778 - val_loss: 0.4220 - val_sparse_categorical_accuracy: 0.8072
# Epoch 50/200
# 45/45 [==============================] - 22s 481ms/step - loss: 0.3037 - sparse_categorical_accuracy: 0.8767 - val_loss: 0.4218 - val_sparse_categorical_accuracy: 0.8128
# Epoch 51/200
# 45/45 [==============================] - 22s 482ms/step - loss: 0.2986 - sparse_categorical_accuracy: 0.8813 - val_loss: 0.4223 - val_sparse_categorical_accuracy: 0.8086
# Epoch 52/200
# 45/45 [==============================] - 22s 482ms/step - loss: 0.2940 - sparse_categorical_accuracy: 0.8854 - val_loss: 0.4172 - val_sparse_categorical_accuracy: 0.8100
# Epoch 53/200
# 45/45 [==============================] - 22s 482ms/step - loss: 0.2927 - sparse_categorical_accuracy: 0.8861 - val_loss: 0.4167 - val_sparse_categorical_accuracy: 0.8169
# Epoch 54/200
# 45/45 [==============================] - 22s 482ms/step - loss: 0.2880 - sparse_categorical_accuracy: 0.8941 - val_loss: 0.4163 - val_sparse_categorical_accuracy: 0.8114
# Epoch 55/200
# 45/45 [==============================] - 22s 483ms/step - loss: 0.2730 - sparse_categorical_accuracy: 0.9003 - val_loss: 0.4158 - val_sparse_categorical_accuracy: 0.8169
# Epoch 56/200
# 45/45 [==============================] - 22s 481ms/step - loss: 0.2769 - sparse_categorical_accuracy: 0.8962 - val_loss: 0.4098 - val_sparse_categorical_accuracy: 0.8155
# Epoch 57/200
# 45/45 [==============================] - 22s 481ms/step - loss: 0.2716 - sparse_categorical_accuracy: 0.8993 - val_loss: 0.4106 - val_sparse_categorical_accuracy: 0.8114
# Epoch 58/200
# 45/45 [==============================] - 22s 482ms/step - loss: 0.2701 - sparse_categorical_accuracy: 0.9007 - val_loss: 0.4098 - val_sparse_categorical_accuracy: 0.8183
# Epoch 59/200
# 45/45 [==============================] - 22s 481ms/step - loss: 0.2689 - sparse_categorical_accuracy: 0.9017 - val_loss: 0.4091 - val_sparse_categorical_accuracy: 0.8183
# Epoch 60/200
# 45/45 [==============================] - 22s 481ms/step - loss: 0.2614 - sparse_categorical_accuracy: 0.9035 - val_loss: 0.4122 - val_sparse_categorical_accuracy: 0.8169
# Epoch 61/200
# 45/45 [==============================] - 22s 482ms/step - loss: 0.2607 - sparse_categorical_accuracy: 0.9062 - val_loss: 0.4073 - val_sparse_categorical_accuracy: 0.8197
# Epoch 62/200
# 45/45 [==============================] - 22s 481ms/step - loss: 0.2709 - sparse_categorical_accuracy: 0.8965 - val_loss: 0.4040 - val_sparse_categorical_accuracy: 0.8183
# Epoch 63/200
# 45/45 [==============================] - 22s 482ms/step - loss: 0.2525 - sparse_categorical_accuracy: 0.9021 - val_loss: 0.4035 - val_sparse_categorical_accuracy: 0.8225
# Epoch 64/200
# 45/45 [==============================] - 22s 481ms/step - loss: 0.2566 - sparse_categorical_accuracy: 0.9080 - val_loss: 0.4021 - val_sparse_categorical_accuracy: 0.8252
# Epoch 65/200
# 18/45 [===========>..................] - ETA: 11s - loss: 0.2472 - sparse_categorical_accuracy: 0.9158
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_410/2194609728.py in <module>
#      21 callbacks = [keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)]
#      22
# ---> 23 model.fit(
#      24     x_train,
#      25     y_train,
#
# /cvmfs/sft.cern.ch/lcg/views/LCG_103cuda/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /cvmfs/sft.cern.ch/lcg/views/LCG_103cuda/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1387               logs = tmp_logs  # No error, now safe to assign to logs.
#    1388               end_step = step + data_handler.step_increment
# -> 1389               callbacks.on_train_batch_end(end_step, logs)
#    1390               if self.stop_training:
#    1391                 break
#
# /cvmfs/sft.cern.ch/lcg/views/LCG_103cuda/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     436     """
#     437     if self._should_call_train_batch_hooks:
# --> 438       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     439
#     440   def on_test_batch_begin(self, batch, logs=None):
#
# /cvmfs/sft.cern.ch/lcg/views/LCG_103cuda/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/keras/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     295       self._call_batch_begin_hook(mode, batch, logs)
#     296     elif hook == 'end':
# --> 297       self._call_batch_end_hook(mode, batch, logs)
#     298     else:
#     299       raise ValueError(
#
# /cvmfs/sft.cern.ch/lcg/views/LCG_103cuda/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/keras/callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     316       self._batch_times.append(batch_time)
#     317
# --> 318     self._call_batch_hook_helper(hook_name, batch, logs)
#     319
#     320     if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# /cvmfs/sft.cern.ch/lcg/views/LCG_103cuda/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/keras/callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     354     for callback in self.callbacks:
#     355       hook = getattr(callback, hook_name)
# --> 356       hook(batch, logs)
#     357
#     358     if self._check_timing:
#
# /cvmfs/sft.cern.ch/lcg/views/LCG_103cuda/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#    1032
#    1033   def on_train_batch_end(self, batch, logs=None):
# -> 1034     self._batch_update_progbar(batch, logs)
#    1035
#    1036   def on_test_batch_end(self, batch, logs=None):
#
# /cvmfs/sft.cern.ch/lcg/views/LCG_103cuda/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/keras/callbacks.py in _batch_update_progbar(self, batch, logs)
#    1104     if self.verbose == 1:
#    1105       # Only block async when verbose = 1.
# -> 1106       logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1107       self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1108
#
# /cvmfs/sft.cern.ch/lcg/views/LCG_103cuda/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/keras/utils/tf_utils.py in sync_to_numpy_or_python_type(tensors)
#     561     return t.item() if np.ndim(t) == 0 else t
#     562
# --> 563   return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     564
#     565
#
# /cvmfs/sft.cern.ch/lcg/views/LCG_103cuda/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     912
#     913   return pack_sequence_as(
# --> 914       structure[0], [func(*x) for x in entries],
#     915       expand_composites=expand_composites)
#     916
#
# /cvmfs/sft.cern.ch/lcg/views/LCG_103cuda/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     912
#     913   return pack_sequence_as(
# --> 914       structure[0], [func(*x) for x in entries],
#     915       expand_composites=expand_composites)
#     916
#
# /cvmfs/sft.cern.ch/lcg/views/LCG_103cuda/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/keras/utils/tf_utils.py in _to_single_numpy_or_python_type(t)
#     555     # Don't turn ragged or sparse tensors to NumPy.
#     556     if isinstance(t, tf.Tensor):
# --> 557       t = t.numpy()
#     558     # Strings, ragged and sparse tensors don't have .item(). Return them as-is.
#     559     if not isinstance(t, (np.ndarray, np.generic)):
#
# /cvmfs/sft.cern.ch/lcg/views/LCG_103cuda/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/tensorflow/python/framework/ops.py in numpy(self)
#    1221     """
#    1222     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1223     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1224     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1225
#
# /cvmfs/sft.cern.ch/lcg/views/LCG_103cuda/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/tensorflow/python/framework/ops.py in _numpy(self)
#    1187   def _numpy(self):
#    1188     try:
# -> 1189       return self._numpy_internal()
#    1190     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1191       raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#
# KeyboardInterrupt:
